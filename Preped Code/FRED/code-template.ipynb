# %% [markdown]
# # 📊 Types of Data on the FRED (Federal Reserve Economic Data) Site
#
# [FRED](https://fred.stlouisfed.org) is a vast repository of economic data curated by the Federal Reserve Bank of St. Louis. Here's what you can find:
#
# ---
#
# ## 1. Macroeconomic Indicators
# - **GDP (Gross Domestic Product)**
# - **CPI (Consumer Price Index)**
# - **PCE (Personal Consumption Expenditures)**
# - **GNP**, **National Income**, **Savings Rates**
#
# ---
#
# ## 2. Labor Market Data
# - **Unemployment Rate**
# - **Labor Force Participation Rate**
# - **Employment-Population Ratio**
# - **Job Openings and Labor Turnover Survey (JOLTS)**
# - **Nonfarm Payrolls**
# - **Wages and Earnings**
#
# ---
#
# ## 3. Inflation & Prices
# - **Consumer Price Index (CPI)**
# - **Producer Price Index (PPI)**
# - **Inflation Expectations**
# - **Core vs. Headline Inflation**
#
# ---
#
# ## 4. Monetary & Financial Data
# - **Federal Funds Rate**
# - **Interest Rates** (Treasury yields, mortgage rates, corporate bonds, etc.)
# - **Money Supply (M1, M2)**
# - **Bank Reserves and Lending**
# - **Yield Curve Data**
#
# ---
#
# ## 5. Housing & Real Estate
# - **Housing Starts**
# - **New and Existing Home Sales**
# - **Home Price Indices** (e.g., Case-Shiller Index)
# - **Mortgage Rates**
# - **Delinquency and Foreclosure Rates**
#
# ---
#
# ## 6. International Economic Data
# - **GDP and Inflation for Other Countries**
# - **Exchange Rates**
# - **Global Trade Balances**
# - **Country-Specific Indicators** (e.g., China, EU, Japan)
#
# ---
#
# ## 7. Trade & Industry
# - **Import and Export Data**
# - **Industrial Production**
# - **Capacity Utilization**
# - **Retail and Wholesale Trade Figures**
#
# ---
#
# ## 8. Government Finance
# - **Federal Government Debt**
# - **Expenditures and Revenues**
# - **Budget Deficits**
# - **State and Local Government Finances**
#
# ---
#
# ## 9. Forecasts and Expectations
# - Data from:
#   - **Survey of Professional Forecasters**
#   - **University of Michigan Consumer Sentiment**

# %% [markdown]
# # 📥 How to Download Data from FRED (Federal Reserve Economic Data)
#
# Follow these steps to find and download datasets from [FRED](https://fred.stlouisfed.org):
#
# ---
#
# ## ✅ Step 1: Visit FRED
#
# Go to: [https://fred.stlouisfed.org](https://fred.stlouisfed.org)
#
# ---
#
# ## 🔎 Step 2: Search for a Data Series
#
# - Use the search bar at the top to find data by:
#   - Keyword (e.g. "unemployment rate", "GDP", "CPI")
#   - Series ID (e.g. `UNRATE`, `GDP`, `CPIAUCSL`)
# - Browse by **Category**, **Source**, or **Release Calendar** if you're not sure what you're looking for.
#
# ---
#
# ## 📊 Step 3: Select a Series
#
# - Click on the series name (e.g. *Unemployment Rate*).
# - You’ll be taken to a page with an interactive graph and summary info.
#
# ---
#
# ## 📤 Step 4: Download the Data
#
# 1. On the series page, click the **"Download"** button (top-right of the graph).
# 2. Choose:
#    - **File format:** CSV, XLSX, or XML
#    - **Date range** (optional)
# 3. Click **“Download”** and save the file to your computer.
#
# ---
#
# ## 🛠 Optional: Adjust Graph Settings Before Download
#
# Before downloading, you can customize:
# - **Units** (e.g. percent change, index value)
# - **Frequency** (monthly, quarterly, annually)
# - **Aggregation method** (average, sum, end of period)

# %%
import pandas_datareader.data as web
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np0
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2024, 12, 31)

# Example: Unemployment Rate (UNRATE)
data = web.DataReader('GDP', 'fred', start, end)
data
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.610
# 2010-04-01  14980.193
# 2010-07-01  15141.607
# 2010-10-01  15309.474
# 2011-01-01  15351.448
# 2011-04-01  15557.539
# 2011-07-01  15647.680
# 2011-10-01  15842.259
# 2012-01-01  16068.805
# 2012-04-01  16207.115
# 2012-07-01  16319.541
# 2012-10-01  16420.419
# 2013-01-01  16648.189
# 2013-04-01  16728.687
# 2013-07-01  16953.838
# 2013-10-01  17192.019
# 2014-01-01  17197.738
# 2014-04-01  17518.508
# 2014-07-01  17804.228
# 2014-10-01  17912.079
# 2015-01-01  18063.529
# 2015-04-01  18279.784
# 2015-07-01  18401.626
# 2015-10-01  18435.137
# 2016-01-01  18525.933
# 2016-04-01  18711.702
# 2016-07-01  18892.639
# 2016-10-01  19089.379
# 2017-01-01  19280.084
# 2017-04-01  19438.643
# 2017-07-01  19692.595
# 2017-10-01  20037.088
# 2018-01-01  20328.553
# 2018-04-01  20580.912
# 2018-07-01  20798.730
# 2018-10-01  20917.867
# 2019-01-01  21111.600
# 2019-04-01  21397.938
# 2019-07-01  21717.171
# 2019-10-01  21933.217
# ...

# %%
sns.lineplot(data)
# Out:
# <Axes: xlabel='DATE'>
